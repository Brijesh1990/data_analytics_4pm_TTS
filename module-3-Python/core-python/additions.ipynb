# %%
a=10
b=20
c=a+b
print("additions of numbers is :",c)
# Out:
# additions of numbers is : 30

# %%
a=int(input("Enter a values :"))
b=int(input("Enter b values :"))
c=a+b
print("Additions of numbers is :",c)
# Out:
# Enter a values : 10
# Enter b values : 40
# Additions of numbers is : 50
